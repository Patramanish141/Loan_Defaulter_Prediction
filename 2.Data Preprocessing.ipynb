# %% [markdown]
# # Step-2 : Data Preprocessing

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
app_train = pd.read_csv(r"C:\Users\manish\OneDrive\Documents\loan-default-prediction\data\application_train.csv")
app_test = pd.read_csv(r"C:\Users\manish\OneDrive\Documents\loan-default-prediction\data\application_test.csv")

# %%
test_ids = app_test['SK_ID_CURR']
train_labels = app_train['TARGET']

# %%
df = pd.concat([app_train.drop(columns=['TARGET']), app_test], ignore_index=True)

# %%
df
# Out:
#         SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002         Cash loans           M            N
# 1           100003         Cash loans           F            N
# 2           100004    Revolving loans           M            Y
# 3           100006         Cash loans           F            N
# 4           100007         Cash loans           M            N
# ...            ...                ...         ...          ...
# 356250      456221         Cash loans           F            N
# 356251      456222         Cash loans           F            N
# 356252      456223         Cash loans           F            Y
# 356253      456224         Cash loans           M            N
# 356254      456250         Cash loans           F            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0                    Y             0          202500.0    406597.5
# 1                    N             0          270000.0   1293502.5
# ...

# %% [markdown]
# ### Correct Anomalies

# %%
df['DAYS_EMPLOYED'].replace({365243: np.nan}, inplace = True)

# %% [markdown]
# ### Handle Categorical Features using One-Hot Encoding

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

# %%
df = pd.get_dummies(data = df, columns = categorical_cols, dummy_na = False)

# %%
df
# Out:
#         SK_ID_CURR  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0           100002             0          202500.0    406597.5      24700.5
# 1           100003             0          270000.0   1293502.5      35698.5
# 2           100004             0           67500.0    135000.0       6750.0
# 3           100006             0          135000.0    312682.5      29686.5
# 4           100007             0          121500.0    513000.0      21865.5
# ...            ...           ...               ...         ...          ...
# 356250      456221             0          121500.0    412560.0      17473.5
# 356251      456222             2          157500.0    622413.0      31909.5
# 356252      456223             1          202500.0    315000.0      33205.5
# 356253      456224             0          225000.0    450000.0      25128.0
# 356254      456250             0          135000.0    312768.0      24709.5
#
# ...

# %% [markdown]
# ### Impute Missing Values

# %%
median_imputer = df.median()
df.fillna(median_imputer, inplace=True)

# %% [markdown]
# ### Split back into Training and Testing sets

# %%
train_df = df[:len(app_train)]
test_df = df[len(app_train):]
